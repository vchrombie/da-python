# %% [markdown]
# ## Basics

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# This is comment!

# %%
bread=10

# %%
print(bread)
# Out:
# 10

# %%
bread=input()
# Out:
# 12

# %%
bread
# Out:
# '12'

# %%
43+5
# Out:
# 48

# %%
'43'+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9622045cc225> in <module>()
# ----> 1 '43'+5
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Tip**: Copy the error and search in [Google](https://www.google.com/).

# %%
8
# Out:
# 8

# %%
8+3
# Out:
# 11

# %% [markdown]
# ### Data Types
#
# Integers: -2, -1, 0, 1, 2, 3, 4, 5
#
# Floating-point numbers: -1.25, -1.0, --0.5, 0.0, 0.5, 1.0, 1.25
#
# Strings: 'a', 'aa', 'aaa', 'Hello!', '11 cats'

# %% [markdown]
# **Math Operations**

# %%
#Addition
2+3
# Out:
# 5

# %%
#Subtraction
8-3
# Out:
# 5

# %%
#Multiplication
2*4
# Out:
# 8

# %%
#Division
42/10
# Out:
# 4.2

# %%
# Exponent
2**4
# Out:
# 16

# %%
#Modulus/Remainder
42%10
# Out:
# 2

# %%
#Floored Quotient
42//10
# Out:
# 4

# %% [markdown]
# **Note**: The precedence rule is BODMAS.
#
# The ** operator is evaluated first; the '*', /, //, and % operators are evaluated next, from left to right; and the + and - operators are evaluated last (also from left to right). You can use parentheses to override the usual precedence if you need to.

# %%
2 + 3 * 6
# Out:
# 20

# %%
(2 + 3) * 6
# Out:
# 30

# %%
48565878 * 578453
# Out:
# 28093077826734

# %%
2 ** 8
# Out:
# 256

# %%
23 / 7
# Out:
# 3.2857142857142856

# %%
23 // 7
# Out:
# 3

# %%
23 % 7
# Out:
# 2

# %%
#extra spaces? no problem 
#python is chill :P
2     +            2
# Out:
# 4

# %%
(5 - 1) * ((7 + 1) / (3 - 1))
# Out:
# 16.0

# %% [markdown]
# #### Explanation
# ![img](https://automatetheboringstuff.com/images/000056.png)

# %%
5 +
# Out:
#   File "<ipython-input-27-4f4744a157be>", line 1
#     5 +
#        ^
# SyntaxError: invalid syntax

# %%
42 + 5 + * 2
# Out:
#   File "<ipython-input-28-16e07b76f178>", line 1
#     42 + 5 + * 2
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# The operations applicable for integers are also applicable for floating numbers too.

# %%
bread=10

# %%
bread
# Out:
# 10

# %%
print(bread)
# Out:
# 10

# %%
butter=3

# %%
bread+butter
# Out:
# 13

# %%
print(bread+butter)
# Out:
# 13

# %%
bread=bread+2
bread
# Out:
# 12

# %%
bread++
# Out:
#   File "<ipython-input-36-83806fb4a738>", line 1
#     bread++
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Note**: Coding in python is entirely different from c/cpp.

# %% [markdown]
# **Strings**

# %%
msg='Hello'

# %%
msg
# Out:
# 'Hello'

# %%
print(msg)
# Out:
# Hello

# %%
msg='Goodbye'

# %%
print(msg)
# Out:
# Goodbye

# %%
len(msg)
print(len(msg))
# Out:
# 7

# %%
msg+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-75cfff91c8ee> in <module>()
# ----> 1 msg+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
msg+'1'
# Out:
# 'Goodbye1'

# %%
msg+str(1)
# Out:
# 'Goodbye1'

# %% [markdown]
# #### Variable Names
#
# **Valid** ✔️
#
# balance
#
# currentBalance
#
# current_balance
#
# _spam
#
# SPAM
#
# account4
#
# ----
#
# **Invalid** ❌
#
# 'hello' (special characters like ' are not allowed)
#
# current-balance (hyphens are not allowed)
#
# 4account (can’t begin with a number)
#
# 42 (can’t begin with a number)
#
# current balance (spaces are not allowed)
#
# total_$um (special characters like $ are not allowed)

# %%
#INPUT: Hi! :)
msg=input()
# Out:
# Hi! :)

# %%
print(msg)
# Out:
# Hi! :)

# %%
print(type(msg))
# Out:
# <class 'str'>

# %%
#INPUT: 12
msg=input()
# Out:
# 12

# %%
print(msg)
# Out:
# 12

# %%
print(type(msg))
# Out:
# <class 'str'>

# %%
#integer input
#INPUT : 12
msg=int(input())
# Out:
# 12

# %%
print(msg)
# Out:
# 12

# %%
print(type(msg))
# Out:
# <class 'int'>

# %%
#change the datatype
msg=str(msg)

# %%
print(msg)
# Out:
# 12

# %%
print(type(msg))
# Out:
# <class 'str'>

# %%
print(int(msg)+1)
# Out:
# 13

# %%
print(float(msg)+1)
# Out:
# 13.0

# %%
print(int(7.7))
# Out:
# 7

# %%
print(int(7.7) + 1)
# Out:
# 8

# %% [markdown]
# Please understand this small program

# %%
print('Hello world!')
print('What is your name?')    # ask for their name
myName = input()
print('It is good to meet you, ' + myName)
print('The length of your name is:')
print(len(myName))
print('What is your age?')    # ask for their age
myAge = input()
print('You will be ' + str(int(myAge) + 1) + ' in a year.')
# Out:
# Hello world!
# What is your name?
# Venu
# It is good to meet you, Venu
# The length of your name is:
# 4
# What is your age?
# 21
# You will be 22 in a year.
